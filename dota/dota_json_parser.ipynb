# %%
import numpy as np
import pandas as pd

# %%
import json
from tqdm import tqdm_notebook

# %%
import os

PATH_TO_DATA = '../input/mlcourse-dota2-win-prediction/'

# %%
def read_matches(matches_file):
    
    MATCHES_COUNT = {
        'test_matches.jsonl': 10000,
        'train_matches.jsonl': 39675,
    }
    _, filename = os.path.split(matches_file)
    total_matches = MATCHES_COUNT.get(filename)
    
    with open(matches_file) as fin:
        for line in tqdm_notebook(fin, total=total_matches):
            yield json.loads(line)

# %%
import collections

MATCH_FEATURES = [
    ('game_time', lambda m: m['game_time']),
    ('game_mode', lambda m: m['game_mode']),
    ('lobby_type', lambda m: m['lobby_type']),
    ('objectives_len', lambda m: len(m['objectives'])),
    ('chat_len', lambda m: len(m['chat'])),
]

PLAYER_FIELDS = [
    'hero_id',
    
    'kills',
    'deaths',
    'assists',
    'denies',
    
    'gold',
    'lh',
    'xp',
    'health',
    'max_health',
    'max_mana',
    'level',

    'x',
    'y',
    
    'stuns',
    'creeps_stacked',
    'camps_stacked',
    'rune_pickups',
    'firstblood_claimed',
    'teamfight_participation',
    'towers_killed',
    'roshans_killed',
    'obs_placed',
    'sen_placed',
]

# %%
def extract_targets_csv(match, targets):
    return collections.OrderedDict([('match_id_hash', match['match_id_hash'])] + [
        (field, targets[field])
        for field in ['game_time', 'radiant_win', 'duration', 'time_remaining', 'next_roshan_team']
    ])

# %%
PLAYER_FIELDS_NEW  = [
    'observers_placed',
    'nearby_creep_death_count',
]

# %%
PLAYER_FIELDS_T  = [
    'gold_t',
    'lh_t',
    'dn_t',
    'xp_t',
]

# %%
PLAYER_FIELDS_N  = [
    'ability_upgrades',
]

# %%
PLAYER_FIELDS_SUM  = [
	'purchase',
	'killed',
	'item_uses',
	'ability_uses',
	'hero_hits',
	'damage',
	'damage_taken',
	'damage_inflictor',
	'killed_by',
	'multi_kills',
	'healing',
	'damage_inflictor_received',
]

# %%
def extract_features_csv(match):
    row = [
        ('match_id_hash', match['match_id_hash']),
    ]
    
    for field, f in MATCH_FEATURES:
        row.append((field, f(match)))
        
    for slot, player in enumerate(match['players']):
        if slot < 5:
            player_name = 'r%d' % (slot + 1)
        else:
            player_name = 'd%d' % (slot - 4)

        for field in PLAYER_FIELDS:
            column_name = '%s_%s' % (player_name, field)
            row.append((column_name, player[field]))
        
        for field in PLAYER_FIELDS_NEW:
            column_name = '%s_%s' % (player_name, field)
            row.append((column_name, player[field]))
            
        for field in PLAYER_FIELDS_T:
            column_name = '%s_%s' % (player_name, field)
            if (len(player['times']) > 1) and (player['times'][len(player['times']) - 1] > 0):
                ans = float((player[field][len(player[field]) - 1])/player['times'][len(player['times']) - 1])
            else:
                ans = 0
            row.append((column_name, ans))
        for field in PLAYER_FIELDS_N:
            column_name = '%s_%s' % (player_name, field)
            row.append((column_name, len(player[field])))
        for field in PLAYER_FIELDS_SUM:
            column_name = '%s_%s' % (player_name, field)
            ans = []
            for key in player[field].keys():
                ans.append(player[field][key])
            row.append((column_name, sum(ans)))
            
    return collections.OrderedDict(row)

# %%
def extractor(path):
    df_features = []
    df_targets  = []

    for match in read_matches(path):
        match_id_hash = match['match_id_hash']
        features = extract_features_csv(match)
        targets = extract_targets_csv(match, match['targets'])

        df_features.append(features)
        df_targets.append(targets)
    return df_features, df_targets

# %%
df_train_features, df_train_targets = extractor(PATH_TO_DATA + 'train_matches.jsonl')
# Out:
# HBox(children=(IntProgress(value=0, max=39675), HTML(value='')))

# %%
df_test_features = []
for match in read_matches(PATH_TO_DATA + 'test_matches.jsonl'):
    match_id_hash = match['match_id_hash']
    features = extract_features_csv(match)

    df_test_features.append(features)
# Out:
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))

# %%
df_train_features = pd.DataFrame.from_records(df_train_features).set_index('match_id_hash')
df_train_targets = pd.DataFrame.from_records(df_train_targets).set_index('match_id_hash')
df_test_features = pd.DataFrame.from_records(df_test_features).set_index('match_id_hash')

# %%
def add_new_features(df_features, matches_file):
    
    # Process raw data and add new features
    for match in read_matches(matches_file):
        match_id_hash = match['match_id_hash']

        # Counting ruined towers for both teams
        radiant_tower_kills = 0
        dire_tower_kills = 0
        for objective in match['objectives']:
            if objective['type'] == 'CHAT_MESSAGE_TOWER_KILL':
                if objective['team'] == 2:
                    radiant_tower_kills += 1
                if objective['team'] == 3:
                    dire_tower_kills += 1

        # Write new features
        df_features.loc[match_id_hash, 'radiant_tower_kills'] = radiant_tower_kills
        df_features.loc[match_id_hash, 'dire_tower_kills'] = dire_tower_kills
        df_features.loc[match_id_hash, 'diff_tower_kills'] = radiant_tower_kills - dire_tower_kills

# %%
# copy the dataframe with features
df_train_features_extended = df_train_features.copy()
df_test_features_extended = df_test_features.copy()

# add new features
add_new_features(df_train_features_extended, PATH_TO_DATA + 'train_matches.jsonl')
add_new_features(df_test_features_extended,  PATH_TO_DATA + 'test_matches.jsonl')

#fill NaN
df_train_features_extended.fillna(0)
df_test_features_extended.fillna(0)
# Out:
# HBox(children=(IntProgress(value=0, max=39675), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
#                                   game_time  game_mode  lobby_type  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa         23          4           0
# 70e5ba30f367cea48793b9003fab9d38       1044         22           7
# 4d9ef74d3a2025d79e9423105fd73d41       1091         22           7
# 2bb79e0c1eaac1608e5a09c8e0c6a555        623         22           7
# bec17f099b01d67edc82dfb5ce735a43       1538         22           7
# ...                                     ...        ...         ...
# 9376a283b50779433de829c79529fe2c       1695         22           7
# bce2bace8b61980d282c9f6a9c69ef9c       2191         22           7
# dc00c2964363b0344a4891bdde235a44        391         22           7
# d75db83f7857720f851a302b00ee6149       1254         22           7
# 1bbaf6d71e197ebf96c6afa3c921000a       1553         22           7
#
#                                   objectives_len  chat_len  r1_hero_id  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa               0         0          79
# 70e5ba30f367cea48793b9003fab9d38              12         6          23
# 4d9ef74d3a2025d79e9423105fd73d41               6         1          64
# 2bb79e0c1eaac1608e5a09c8e0c6a555               1         0          41
# bec17f099b01d67edc82dfb5ce735a43               7        11          40
# ...                                          ...       ...         ...
# 9376a283b50779433de829c79529fe2c              18         1          93
# bce2bace8b61980d282c9f6a9c69ef9c              12         9          40
# dc00c2964363b0344a4891bdde235a44               1         0          21
# d75db83f7857720f851a302b00ee6149               7         3          90
# 1bbaf6d71e197ebf96c6afa3c921000a               9        12          14
#
#                                   r1_kills  r1_deaths  r1_assists  r1_denies  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa         0          0           0          0
# 70e5ba30f367cea48793b9003fab9d38         3          5           7          1
# 4d9ef74d3a2025d79e9423105fd73d41         3          1           7          1
# 2bb79e0c1eaac1608e5a09c8e0c6a555         0          0           1          2
# bec17f099b01d67edc82dfb5ce735a43         2          7          12          0
# ...                                    ...        ...         ...        ...
# 9376a283b50779433de829c79529fe2c         2          6           6          5
# bce2bace8b61980d282c9f6a9c69ef9c         3          5           8          4
# dc00c2964363b0344a4891bdde235a44         0          1           0          8
# d75db83f7857720f851a302b00ee6149         0          4           6          0
# 1bbaf6d71e197ebf96c6afa3c921000a         5          7           4          5
#
#                                   ...  d5_damage  d5_damage_taken  \
# match_id_hash                     ...
# 30cc2d778dca82f2edb568ce9b585caa  ...        185              187
# 70e5ba30f367cea48793b9003fab9d38  ...      12491             7863
# 4d9ef74d3a2025d79e9423105fd73d41  ...      30441            10133
# 2bb79e0c1eaac1608e5a09c8e0c6a555  ...      16860             9002
# bec17f099b01d67edc82dfb5ce735a43  ...      77162            23133
# ...                               ...        ...              ...
# 9376a283b50779433de829c79529fe2c  ...      70957            13068
# bce2bace8b61980d282c9f6a9c69ef9c  ...     153285            28212
# dc00c2964363b0344a4891bdde235a44  ...       4887             2302
# d75db83f7857720f851a302b00ee6149  ...      68463             8263
# 1bbaf6d71e197ebf96c6afa3c921000a  ...      18198             8913
#
#                                   d5_damage_inflictor  d5_killed_by  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa                  185             0
# 70e5ba30f367cea48793b9003fab9d38                 4785             5
# 4d9ef74d3a2025d79e9423105fd73d41                 7722             5
# 2bb79e0c1eaac1608e5a09c8e0c6a555                 4209             4
# bec17f099b01d67edc82dfb5ce735a43                 9706             2
# ...                                               ...           ...
# 9376a283b50779433de829c79529fe2c                 9707             4
# bce2bace8b61980d282c9f6a9c69ef9c                14360             7
# dc00c2964363b0344a4891bdde235a44                  910             1
# d75db83f7857720f851a302b00ee6149                 7300             3
# 1bbaf6d71e197ebf96c6afa3c921000a                 7132             3
#
#                                   d5_multi_kills  d5_healing  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa               0           0
# 70e5ba30f367cea48793b9003fab9d38               0         280
# 4d9ef74d3a2025d79e9423105fd73d41               0        1407
# 2bb79e0c1eaac1608e5a09c8e0c6a555               0          85
# bec17f099b01d67edc82dfb5ce735a43               2        7586
# ...                                          ...         ...
# 9376a283b50779433de829c79529fe2c               2         470
# bce2bace8b61980d282c9f6a9c69ef9c               1        5220
# dc00c2964363b0344a4891bdde235a44               0         400
# d75db83f7857720f851a302b00ee6149               0        4793
# 1bbaf6d71e197ebf96c6afa3c921000a               0        9671
#
#                                   d5_damage_inflictor_received  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa                           187
# 70e5ba30f367cea48793b9003fab9d38                          6343
# 4d9ef74d3a2025d79e9423105fd73d41                          7928
# 2bb79e0c1eaac1608e5a09c8e0c6a555                          3791
# bec17f099b01d67edc82dfb5ce735a43                         10324
# ...                                                        ...
# 9376a283b50779433de829c79529fe2c                          9109
# bce2bace8b61980d282c9f6a9c69ef9c                         20318
# dc00c2964363b0344a4891bdde235a44                          1874
# d75db83f7857720f851a302b00ee6149                          5300
# 1bbaf6d71e197ebf96c6afa3c921000a                          6321
#
#                                   radiant_tower_kills  dire_tower_kills  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa                  0.0               0.0
# 70e5ba30f367cea48793b9003fab9d38                  7.0               2.0
# 4d9ef74d3a2025d79e9423105fd73d41                  4.0               1.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555                  0.0               0.0
# bec17f099b01d67edc82dfb5ce735a43                  2.0               4.0
# ...                                               ...               ...
# 9376a283b50779433de829c79529fe2c                  0.0               8.0
# bce2bace8b61980d282c9f6a9c69ef9c                  6.0               3.0
# dc00c2964363b0344a4891bdde235a44                  0.0               0.0
# d75db83f7857720f851a302b00ee6149                  4.0               0.0
# 1bbaf6d71e197ebf96c6afa3c921000a                  2.0               6.0
#
#                                   diff_tower_kills
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa               0.0
# 70e5ba30f367cea48793b9003fab9d38               5.0
# 4d9ef74d3a2025d79e9423105fd73d41               3.0
# 2bb79e0c1eaac1608e5a09c8e0c6a555               0.0
# bec17f099b01d67edc82dfb5ce735a43              -2.0
# ...                                            ...
# 9376a283b50779433de829c79529fe2c              -8.0
# bce2bace8b61980d282c9f6a9c69ef9c               3.0
# dc00c2964363b0344a4891bdde235a44               0.0
# d75db83f7857720f851a302b00ee6149               4.0
# 1bbaf6d71e197ebf96c6afa3c921000a              -4.0
#
# [10000 rows x 438 columns]

# %%
col = ['purchase',
 'killed',
 'item_uses',
 'ability_uses',
 'hero_hits',
 'damage',
 'damage_taken',
 'damage_inflictor',
 'killed_by',
 'multi_kills',
 'healing',
 'damage_inflictor_received',
 'ability_upgrades',
 'gold_t',
 'lh_t',
 'dn_t',
 'xp_t',
 'observers_placed',
 'nearby_creep_death_count',
 'kills',
 'deaths',
 'assists',
 'denies',
 'gold',
 'lh',
 'xp',
 'health',
 'max_health',
 'max_mana',
 'level',
 'x',
 'y',
 'stuns',
 'creeps_stacked',
 'camps_stacked',
 'rune_pickups',
 'firstblood_claimed',
 'teamfight_participation',
 'towers_killed',
 'roshans_killed',
 'obs_placed',
 'sen_placed']

# %%
def add_calc_features(df, col):
    metrics = [
                    'total_',
                    'std_',
                    'mean_',
                    'min_',
                    'max_'
              ]
    
    for c in col:
         
        r_columns = [f'r{i}_{c}' for i in range(1, 6)]
        d_columns = [f'd{i}_{c}' for i in range(1, 6)]
        
        for m in metrics:
            df['r_' + m + c] = df[r_columns].sum(1)
            df['d_' + m + c] = df[d_columns].sum(1)
            
            ratio_col = m + c + '_ratio'
            df[ratio_col] = 0
            ind = df[df['d_' + m + c] >  0].index
            df.loc[ind, ratio_col] = df.loc[ind, 'r_' + m + c]/df.loc[ind, 'd_' + m + c]

# %%
# copy the dataframe with features
df_train_features_extended2 = df_train_features_extended.copy()
df_test_features_extended2  = df_test_features_extended.copy()

# add calc features
add_calc_features(df_train_features_extended2, col)
add_calc_features(df_test_features_extended2,  col)

# %%
df_train_features_extended2.to_csv('df_train_features_ext.csv')
df_test_features_extended2.to_csv('df_test_features_ext.csv')
df_train_targets.to_csv('df_train_targets.csv')

# %%
df_train_features_extended2['max_kills_ratio']
# Out:
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a    0.000000
# b9c57c450ce74a2af79c9ce96fac144d    5.333333
# 6db558535151ea18ca70a6892197db41    0.000000
# 46a0ddce8f7ed2a8d9bd5edcbb925682    6.000000
# b1b35ff97723d9b7ade1c9c3cf48f770    0.500000
#                                       ...
# defd0caeed6ea83d7d5fbdec013fe7d1    0.593750
# bc7a87ed5f9c2bca55f9f7a93da0b0c5    1.000000
# e2ca68ac1a6847f4a37f6c9c8ee8695b    0.222222
# 47ad6454ede66c1c78fdaa9391dfc556    1.076923
# 9928dfde50efcbdb2055da23dcdbc101    1.500000
# Name: max_kills_ratio, Length: 39675, dtype: float64
